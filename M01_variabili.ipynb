# %% [markdown]
# <a href="https://colab.research.google.com/github/giruffo/python-for-process-engineers/blob/main/M01_variabili.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🐍 Modulo 01 – Variabili e tipi numerici

**Scenario reale:** Serbatoio di stoccaggio
**Obiettivo:** calcolare riempimento e volume disponibile


capacita_totale_L = 5000
volume_attuale_L = 3750

percentuale_riempimento = (volume_attuale_L / capacita_totale_L) * 100
volume_disponibile_L = capacita_totale_L - volume_attuale_L

print(f"Riempimento: {percentuale_riempimento:.1f}%")
print(f"Disponibile: {volume_disponibile_L} L")

if percentuale_riempimento > 90:
    print("⚠️ Riempimento oltre il limite")

# %% [markdown]
# # 🧪 ESERCIZIO
# # Cambia i valori e verifica quando scatta l'allarme

# %%
capacita_totale_L = 8000
volume_attuale_L = 3750
# TODO: completa i calcoli
if percentuale_riempimento > 90:
    print("⚠️ ALLARME ATTIVO")
else:
    print("Livello OK")

# %% [markdown]
# ### ⚠️ Errori comuni
# - Dimenticare di moltiplicare per 100
# - Usare nomi di variabili senza unità
# - Confrontare float con == invece che >
